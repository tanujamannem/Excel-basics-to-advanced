# %% [markdown]
# # 📘 Day 27 — Excel Shortcuts & Productivity Techniques
#
# ---
#
# # ⭐ 1. Why Shortcuts Matter for Data Analysts
#
# Excel shortcuts:
# - Save time
# - Improve accuracy
# - Make you look confident in interviews
# - Are EXPECTED from Data Analysts
#
# Interviewers often ask:
# “Which Excel shortcuts do you use daily?”
#
# ---
#
# # ⭐ 2. Dataset for Practice (Copy to Excel)
#
# Employee ID | Name | Department | Salary | Joining Date
# ----------- | ---- | ---------- | ------ | ------------
# E201 | Asha | IT | 50000 | 01-01-2023
# E202 | Rahul | HR | 42000 | 15-02-2023
# E203 | Meera | IT | 60000 | 10-03-2023
# E204 | Rohit | Finance | 55000 | 05-04-2023
# E205 | Tina | HR | 48000 | 20-05-2023
#
# Range: A1:E6
#
# ---
#
# # ⭐ 3. Essential Navigation Shortcuts
#
# Ctrl + Arrow Keys → Jump to last filled cell
# Ctrl + Home → Go to A1
# Ctrl + End → Go to last used cell
# Ctrl + Page Up / Page Down → Switch sheets
#
# ---
#
# # ⭐ 4. Selection Shortcuts
#
# Ctrl + Shift + Arrow → Select continuous data
# Ctrl + A → Select entire table
# Shift + Space → Select row
# Ctrl + Space → Select column
#
# ---
#
# # ⭐ 5. Editing Shortcuts
#
# F2 → Edit active cell
# Ctrl + Enter → Fill selected cells
# Ctrl + D → Fill Down
# Ctrl + R → Fill Right
# Ctrl + Z → Undo
# Ctrl + Y → Redo
#
# ---
#
# # ⭐ 6. Formatting Shortcuts
#
# Ctrl + B → Bold
# Ctrl + I → Italic
# Ctrl + U → Underline
# Ctrl + 1 → Format Cells dialog
# Alt + H + B → Apply borders
# Alt + H + C → Center align
#
# ---
#
# # ⭐ 7. Data Handling Shortcuts
#
# Ctrl + T → Convert range to table
# Ctrl + Shift + L → Apply / Remove filter
# Alt + A + T → Remove duplicates
# Ctrl + ; → Insert current date
# Ctrl + Shift + : → Insert current time
#
# ---
#
# # ⭐ 8. Formula & Calculation Shortcuts
#
# Alt + = → AutoSum
# F4 → Toggle absolute / relative reference
# Ctrl + ` → Show formulas
# Shift + F9 → Calculate active sheet
#
# ---
#
# # ⭐ 9. Productivity Tips (REAL WORK)
#
# ✔ Freeze headers: View → Freeze Top Row
# ✔ Split screen: View → Split
# ✔ Remove gridlines: View → Gridlines
# ✔ Quick chart: Alt + F1
# ✔ Paste Special: Ctrl + Alt + V
#
# ---
#
# # ⭐ 10. Practice Questions
#
# Q1. Shortcut to convert data to table?
# Answer: Ctrl + T
#
# Q2. Shortcut to apply filter?
# Answer: Ctrl + Shift + L
#
# Q3. Shortcut to edit cell?
# Answer: F2
#
# Q4. Shortcut to autosum?
# Answer: Alt + =
#
# Q5. Shortcut to format cells?
# Answer: Ctrl + 1
#
# Q6. Shortcut to fill down?
# Answer: Ctrl + D
#
# Q7. Shortcut to remove duplicates?
# Answer: Alt + A + T
#
# Q8. Shortcut to select column?
# Answer: Ctrl + Space
#
# Q9. Shortcut to show formulas?
# Answer: Ctrl + `
#
# Q10. Shortcut to freeze panes?
# Answer: View → Freeze Panes (no direct shortcut)
#
# ---
#
# # ⭐ 11. Interview Questions
#
# Q1. Why are shortcuts important?
# Answer: Speed and efficiency.
#
# Q2. Which shortcuts do you use daily?
# Answer: Ctrl+T, Ctrl+Shift+L, F2, Alt+=
#
# Q3. Do shortcuts improve productivity?
# Answer: Yes.
#
# Q4. Shortcut to apply table formatting?
# Answer: Ctrl + T
#
# Q5. Shortcut to repeat last action?
# Answer: F4
#
# Q6. How to quickly analyze large data?
# Answer: Filters + shortcuts.
#
# Q7. Can shortcuts reduce errors?
# Answer: Yes.
#
# Q8. Do analysts memorize all shortcuts?
# Answer: No, only frequent ones.
#
# Q9. Shortcut to insert current date?
# Answer: Ctrl + ;
#
# Q10. Are shortcuts asked in interviews?
# Answer: Yes.
