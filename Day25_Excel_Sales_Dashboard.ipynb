# %% [markdown]
# # 📘 Day 25 — Excel Dashboard Project (Sales Dashboard)
#
# ---
#
# # ⭐ 1. Project Overview
#
# We will build **ONE complete Sales Dashboard** using Excel.
#
# This project combines:
# - Data cleaning
# - Pivot tables
# - KPIs
# - Charts
# - Slicers
# - Professional layout
#
# ---
#
# # ⭐ 2. Dataset for Project (Copy to Excel)
#
# Order ID | Date       | Region | Category     | Product     | Sales | Quantity
# -------- | ---------- | ------ | ------------ | ----------- | ----- | --------
# O101     | 01-01-2024 | East   | Electronics  | Laptop      | 55000 | 4
# O102     | 02-01-2024 | West   | Furniture    | Chair       | 12000 | 6
# O103     | 03-01-2024 | North  | Electronics  | Mobile      | 30000 | 8
# O104     | 04-01-2024 | South  | Stationery   | Pen         | 5000  | 50
# O105     | 05-01-2024 | East   | Furniture    | Table       | 25000 | 2
# O106     | 06-01-2024 | West   | Electronics  | Monitor     | 18000 | 5
# O107     | 07-01-2024 | North  | Stationery   | Notebook    | 7000  | 20
# O108     | 08-01-2024 | South  | Furniture    | Sofa        | 40000 | 1
# O109     | 09-01-2024 | East   | Electronics  | Headphones  | 9000  | 10
# O110     | 10-01-2024 | West   | Stationery   | Marker      | 6000  | 15
#
# Range: A1:G11
#
# ---
#
# # ⭐ 3. Prepare Data
#
# ### ✔ Step 1: Convert to Table
# 1. Select entire dataset
# 2. Press **Ctrl + T**
# 3. Check **My table has headers**
# 4. Click OK
#
# Rename table to: **Sales_Data**
#
# ---
#
# # ⭐ 4. Create Pivot Tables
#
# Create a new sheet named **Pivot_Data**
#
# ---
#
# ## 🔹 Pivot 1: Total Sales (KPI)
# - Values → Sales (Sum)
#
# ---
#
# ## 🔹 Pivot 2: Total Quantity (KPI)
# - Values → Quantity (Sum)
#
# ---
#
# ## 🔹 Pivot 3: Total Orders (KPI)
# - Values → Order ID (Count)
#
# ---
#
# ## 🔹 Pivot 4: Sales by Region
# - Rows → Region
# - Values → Sales (Sum)
#
# ---
#
# ## 🔹 Pivot 5: Sales by Category
# - Rows → Category
# - Values → Sales (Sum)
#
# ---
#
# # ⭐ 5. Build KPI Cards
#
# Create a new sheet named **Dashboard**
#
# ---
#
# ## 🔹 KPI Cards
#
# ### Total Sales
# - Copy Total Sales value
# - Paste on Dashboard
# - Font size: 32
# - Label: **Total Sales**
#
# ---
#
# ### Total Quantity
# - Copy Total Quantity
# - Same formatting
#
# ---
#
# ### Total Orders
# - Copy Order Count
# - Same formatting
#
# ---
#
# # ⭐ 6. Create Charts
#
# ---
#
# ## 🔹 Sales by Region Chart
# 1. Select Pivot 4
# 2. Insert → Column Chart
# 3. Remove title
# 4. Add data labels
#
# ---
#
# ## 🔹 Sales by Category Chart
# 1. Select Pivot 5
# 2. Insert → Bar Chart
# 3. Resize and align
#
# ---
#
# # ⭐ 7. Add Slicers
#
# ---
#
# ## 🔹 Insert Slicers
# 1. Click any pivot
# 2. PivotTable Analyze → Insert Slicer
# 3. Select:
#    - Region
#    - Category
# 4. Click OK
#
# ---
#
# ## 🔹 Connect Slicers to All Pivots
# 1. Click slicer
# 2. Slicer → Report Connections
# 3. Check all pivots
# 4. Click OK
#
# ---
#
# # ⭐ 8. Final Dashboard Layout
#
# ---
#
# ### Layout Structure
# - KPIs on top
# - Charts in middle
# - Slicers on left/right
#
# ---
#
# ### Design Tips
# - Remove gridlines
# - Use same font
# - Avoid bright colors
# - Keep white background
#
# ---
#
# # ⭐ 9. Practice Questions
#
# Q1. Why use pivot tables for dashboards?
# Answer: Fast and dynamic summarization
#
# Q2. Why convert data to table?
# Answer: Dynamic data range
#
# Q3. What does slicer do?
# Answer: Filters data visually
#
# Q4. Best chart for category comparison?
# Answer: Bar chart
#
# Q5. KPI meaning?
# Answer: Key Performance Indicator
#
# Q6. Should dashboard have many charts?
# Answer: No
#
# Q7. Can slicers control KPIs?
# Answer: Yes
#
# Q8. Best position for KPIs?
# Answer: Top
#
# Q9. What makes dashboard professional?
# Answer: Simplicity
#
# Q10. Can Excel dashboards be interactive?
# Answer: Yes
#
# ---
#
# # ⭐ 10. Interview Questions
#
# Q1. Explain how you built this dashboard.
# Answer: Used tables, pivots, KPIs, charts, slicers.
#
# Q2. Why use slicers instead of filters?
# Answer: User-friendly.
#
# Q3. What happens when data increases?
# Answer: Dashboard updates automatically.
#
# Q4. Can Excel dashboards handle large data?
# Answer: Yes (with pivots).
#
# Q5. Difference between report and dashboard?
# Answer: Dashboard is interactive.
#
# Q6. What KPIs did you choose and why?
# Answer: Sales, quantity, orders.
#
# Q7. How to improve dashboard performance?
# Answer: Use pivots and clean data.
#
# Q8. Can this dashboard be shared?
# Answer: Yes.
#
# Q9. What Excel skills does this project show?
# Answer: End-to-end analysis.
#
# Q10. Would you use Power BI instead?
# Answer: For large datasets.
